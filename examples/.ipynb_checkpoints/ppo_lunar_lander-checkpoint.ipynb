# %% [markdown]
# # PPO Breakout Example
#
# ### Atari Breakout
#
# Please do note that this example may take a long time to train.
#
# With the default 4 threads runnning on an 8-core CPU with a GTX 1080 Ti, it will take several hours to train to a decent level of play.
#
# Running on a platform with more GPU power and a larger cluster of CPUs could siginificantly reduce training time.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPool2D, Flatten
import gym
from ludus.policies import PPOTrainer
from ludus.env import EnvController, make_lunar_lander_c

# %%
env = make_lunar_lander_c() # This instance of the environment is only used
                              # to get action dimensions

# Creating a conv net for the policy and value estimator
obs_op = Input(shape=env.observation_space.shape)
dense1 = Dense(32, activation='tanh')(obs_op)
dense2 = Dense(32, activation='tanh')(dense1)
act_probs_op = Dense(env.action_space.shape[0])(dense2) # Prob dist over possible actions

# Output value of observed state
vdense1 = Dense(32, activation='tanh')(obs_op)
vdense2 = Dense(32, activation='tanh')(vdense1)
value_op = Dense(1)(vdense2)

# Wrap a Proximal Policy Optimization Trainer on top of the network
network = PPOTrainer(obs_op, act_probs_op, value_op, act_type='continuous', ppo_iters=40, entropy_coef=1.)

# %%
n_episodes = 1000000 # Total episodes of data to collect
max_steps = 400 # Max number of frames per game
batch_size = 8 # Smaller = faster, larger = stabler
print_freq = 10 # How many training updates between printing progress

# %%
# Create the environment controller for generating game data
ec = EnvController(make_lunar_lander_c, n_threads=4)
# Set the preprocessing function for observations
ec.set_act_transform(lambda x: np.clip(x, -1, 1))

# %%
update_rewards = []

for i in range(int(n_episodes / batch_size)):
    ec.sim_episodes(network, batch_size, max_steps) # Simualate env to generate data
    update_rewards.append(ec.get_avg_reward()) # Append rewards to reward tracker list
    dat = ec.get_data() # Get all the data gathered
    network.train(dat) # Train the network with PPO
    if i != 0 and i % print_freq == 0:
        print(f'Update #{i}, Avg Reward: {np.mean(update_rewards[-print_freq:])}') # Print an update
# Out:
# Update #10, Avg Reward: -951.5817344531704
# Update #20, Avg Reward: -977.9308919496021
# Update #30, Avg Reward: -1069.3685113132105
# Update #40, Avg Reward: -1181.0752731930672
# Update #50, Avg Reward: -985.9168143248814
# Update #60, Avg Reward: -1070.654274490439
# Update #70, Avg Reward: -1229.3568425367146
# Update #80, Avg Reward: -1139.5595003235844
# Update #90, Avg Reward: -1129.9825958779925
# Update #100, Avg Reward: -1031.7554481750685
# Update #110, Avg Reward: -1217.3933648142279
# Update #120, Avg Reward: -1131.3286765103576
# Update #130, Avg Reward: -1201.2071976323532
# Update #140, Avg Reward: -1027.4117211911807
# Update #150, Avg Reward: -1017.6186943137994
# Update #160, Avg Reward: -1056.6364737022805
# Update #170, Avg Reward: -882.8073535089819
# Update #180, Avg Reward: -137.12347564251718
# Update #190, Avg Reward: -127.97753084625961
# Update #200, Avg Reward: -130.21208005978485
# Update #210, Avg Reward: -124.86524294932443
# Update #220, Avg Reward: -136.08882896017
# Update #230, Avg Reward: -138.94800859013566
# Update #240, Avg Reward: -125.59223390376262
# Update #250, Avg Reward: -133.70353007434153
# Update #260, Avg Reward: -130.93080083440637
# Update #270, Avg Reward: -116.69526231972183
# Update #280, Avg Reward: -132.13442514653826
# Update #290, Avg Reward: -114.69822924797802
# Update #300, Avg Reward: -133.98451671817173
# Update #310, Avg Reward: -122.22985330554658
# Update #320, Avg Reward: -141.15657073979085
# Update #330, Avg Reward: -135.14274214414576
# Update #340, Avg Reward: -132.73043732418287
# Update #350, Avg Reward: -129.18623821381203
# Update #360, Avg Reward: -122.89756842777255
# Update #370, Avg Reward: -138.42012619495628
# Update #380, Avg Reward: -133.06797487769538
# Update #390, Avg Reward: -134.20554794254954
# Update #400, Avg Reward: -132.08150577491386
# Update #410, Avg Reward: -122.21848744186825
# Update #420, Avg Reward: -119.70029697222633
# Update #430, Avg Reward: -135.1621925736295
# Update #440, Avg Reward: -131.50908432353174
# Update #450, Avg Reward: -136.37170969120766
# Update #460, Avg Reward: -130.17774945723386
# Update #470, Avg Reward: -128.82911186332385
# Update #480, Avg Reward: -134.59858409925783
# Update #490, Avg Reward: -126.33822174692793
# Update #500, Avg Reward: -134.97413231602562
# Update #510, Avg Reward: -130.6224683347026
# Update #520, Avg Reward: -120.62774312282144
# Update #530, Avg Reward: -131.30172705366672
# Update #540, Avg Reward: -121.9997496832088
# Update #550, Avg Reward: -123.10599162509561
# Update #560, Avg Reward: -133.3253546364825
# Update #570, Avg Reward: -136.53350746123982
# Update #580, Avg Reward: -129.82628005600822
# Update #590, Avg Reward: -126.56235177801318
# Update #600, Avg Reward: -148.43156272709584
# Update #610, Avg Reward: -137.31263772722005
# Update #620, Avg Reward: -125.46119993327679
# Update #630, Avg Reward: -136.56447798145018
# Update #640, Avg Reward: -127.62900843893287
# Update #650, Avg Reward: -125.94428808418559
# Update #660, Avg Reward: -125.51128893756625
# Update #670, Avg Reward: -130.90100387319
# Update #680, Avg Reward: -131.57926820516792
# Update #690, Avg Reward: -127.1162195611422
# Update #700, Avg Reward: -116.98390836748777
# Update #710, Avg Reward: -137.0410227843214
# Update #720, Avg Reward: -125.35811253901731
# Update #730, Avg Reward: -129.01318031857485
# Update #740, Avg Reward: -129.58783154771973
# Update #750, Avg Reward: -124.02827209581714
# Update #760, Avg Reward: -139.6978279501114
# Update #770, Avg Reward: -140.85156658859034
# Update #780, Avg Reward: -128.0298380052858
# Update #790, Avg Reward: -132.36184114670652
# Update #800, Avg Reward: -128.4086591635351
# Update #810, Avg Reward: -132.399775447553
# Update #820, Avg Reward: -128.48612053328733
# Update #830, Avg Reward: -144.8666585774654
# Update #840, Avg Reward: -132.66142207603139
# Update #850, Avg Reward: -138.3516924097208
# Update #860, Avg Reward: -118.56371139412843
# Update #870, Avg Reward: -124.45710146748641
# Update #880, Avg Reward: -120.24210543266614
# Update #890, Avg Reward: -135.45455615827623
# Update #900, Avg Reward: -114.6621356042122
# Update #910, Avg Reward: -125.67238647070721
# Update #920, Avg Reward: -123.56495677130947
# Update #930, Avg Reward: -124.78627891263281
# Update #940, Avg Reward: -122.39397050962532
# Update #950, Avg Reward: -140.79388397133997
# Update #960, Avg Reward: -137.7600176456827
# Update #970, Avg Reward: -136.32555755538374
# Update #980, Avg Reward: -131.83334292520797
# Update #990, Avg Reward: -130.69690181949778
# Update #1000, Avg Reward: -138.14154043798194
# Update #1010, Avg Reward: -129.68230512977624
# Update #1020, Avg Reward: -125.77217271782597
# Update #1030, Avg Reward: -134.53630996846488
# Update #1040, Avg Reward: -135.3933786011923
# Update #1050, Avg Reward: -150.25450936946942
# Update #1060, Avg Reward: -128.4685830195388
# Update #1070, Avg Reward: -121.57396919022779
# Update #1080, Avg Reward: -135.80975759278766
# Update #1090, Avg Reward: -138.28076515691185
# Update #1100, Avg Reward: -127.28687808493075
# Update #1110, Avg Reward: -132.4393128243749
# Update #1120, Avg Reward: -129.07677479305602
# Update #1130, Avg Reward: -139.52627155911696
# Update #1140, Avg Reward: -120.13284965247703
# Update #1150, Avg Reward: -136.69875295067501
# Update #1160, Avg Reward: -127.02682926229025
# Update #1170, Avg Reward: -126.21652868252079
# Update #1180, Avg Reward: -142.2340756018525
# Update #1190, Avg Reward: -130.80208944634612
# Update #1200, Avg Reward: -140.38204716741024
# Update #1210, Avg Reward: -132.14272546969423
# Update #1220, Avg Reward: -131.44795718303175
# Update #1230, Avg Reward: -129.46814289400987
# Update #1240, Avg Reward: -129.63947393098564
# Update #1250, Avg Reward: -132.99344955286642
# Update #1260, Avg Reward: -134.91842843774367
# Update #1270, Avg Reward: -126.53490567595459
# Update #1280, Avg Reward: -133.84640704191955
# Update #1290, Avg Reward: -125.34032203845632
# Update #1300, Avg Reward: -127.25099974025622
# Update #1310, Avg Reward: -136.6744163802138
# Update #1320, Avg Reward: -126.64626707794105
# Update #1330, Avg Reward: -136.39828398797573
# Update #1340, Avg Reward: -132.70939184015808
# Update #1350, Avg Reward: -132.58945651939044
# Update #1360, Avg Reward: -134.27296622426326
# Update #1370, Avg Reward: -138.86013053577463
# Update #1380, Avg Reward: -125.92339340834685
# Update #1390, Avg Reward: -134.4007282984797
# Update #1400, Avg Reward: -133.01420107631893
# Update #1410, Avg Reward: -125.15192627402371
# Update #1420, Avg Reward: -131.73513811718084
# Update #1430, Avg Reward: -138.65446424787928
# Update #1440, Avg Reward: -130.50130116368368
# Update #1450, Avg Reward: -137.84377738135962
# Update #1460, Avg Reward: -135.76225647587617
# Update #1470, Avg Reward: -125.96662986700747
# Update #1480, Avg Reward: -130.88417653580078
# Update #1490, Avg Reward: -142.4903373401234
# Update #1500, Avg Reward: -139.99678062653567
# Update #1510, Avg Reward: -129.6510877371429
# Update #1520, Avg Reward: -125.6732069067103
# Update #1530, Avg Reward: -124.18695232800094
# Update #1540, Avg Reward: -128.641440391294
# Update #1550, Avg Reward: -121.12282896658903
# Update #1560, Avg Reward: -127.5223551205872
# Update #1570, Avg Reward: -132.13506031034012
# Update #1580, Avg Reward: -115.8120486952029
# Update #1590, Avg Reward: -133.28227774080466
# Update #1600, Avg Reward: -128.13104529971523
# Update #1610, Avg Reward: -130.95271195182897
# Update #1620, Avg Reward: -138.66879313142675
# Update #1630, Avg Reward: -123.10387721715279
# Update #1640, Avg Reward: -125.29604215330842
# Update #1650, Avg Reward: -134.06507110203898
# Update #1660, Avg Reward: -136.0927563191529
# Update #1670, Avg Reward: -120.88135782415786
# Update #1680, Avg Reward: -123.12183649183969
# Update #1690, Avg Reward: -138.4274217263424
# Update #1700, Avg Reward: -139.88345038823954
# Update #1710, Avg Reward: -141.17433425466183
# Update #1720, Avg Reward: -118.18099001247523
# Update #1730, Avg Reward: -131.076222341372
# Update #1740, Avg Reward: -135.8263441996023
# Update #1750, Avg Reward: -126.85229532611729
# Update #1760, Avg Reward: -132.526958088109
# Update #1770, Avg Reward: -127.64144361156039
# Update #1780, Avg Reward: -128.13460213107538
# Update #1790, Avg Reward: -134.20674240784152
# Update #1800, Avg Reward: -128.2906649833911
# Update #1810, Avg Reward: -134.30156144231188
# Update #1820, Avg Reward: -119.05260401090781
# Update #1830, Avg Reward: -132.436072810815
# Update #1840, Avg Reward: -135.19286775250276
# Update #1850, Avg Reward: -135.317635565049
# Update #1860, Avg Reward: -137.00554115908375
# Update #1870, Avg Reward: -139.45730175280167
# Update #1880, Avg Reward: -126.81659599457342
# Update #1890, Avg Reward: -136.60378637794207
# Update #1900, Avg Reward: -136.32408766865723
# Update #1910, Avg Reward: -139.21952133055976
# Update #1920, Avg Reward: -132.01249972143793
# Update #1930, Avg Reward: -135.7232598100644
# Update #1940, Avg Reward: -135.11305079415746
# Update #1950, Avg Reward: -132.82381343554465
# Update #1960, Avg Reward: -127.49525285831169
# Update #1970, Avg Reward: -134.27786641431106
# Update #1980, Avg Reward: -134.28838613036237
# Update #1990, Avg Reward: -141.29897576568595
# Update #2000, Avg Reward: -141.94559430687528
# Update #2010, Avg Reward: -137.4089898235612
# Update #2020, Avg Reward: -132.68127491633157
# Update #2030, Avg Reward: -131.94396543184635
# Update #2040, Avg Reward: -127.19429982583713
# Update #2050, Avg Reward: -139.14191255184684
# Update #2060, Avg Reward: -131.4703068376381
# Update #2070, Avg Reward: -137.48142947694652
# Update #2080, Avg Reward: -135.04999235011712
# Update #2090, Avg Reward: -129.37386966021455
# Update #2100, Avg Reward: -130.31572580358795
# Update #2110, Avg Reward: -136.58248263005603
# Update #2120, Avg Reward: -136.39597144929544
# Update #2130, Avg Reward: -136.13180993930595
# Update #2140, Avg Reward: -125.88207790349115
# Update #2150, Avg Reward: -131.12956750234332
# Update #2160, Avg Reward: -126.37154675375987
# Update #2170, Avg Reward: -120.16459451015461
# Update #2180, Avg Reward: -131.4114702318514
# Update #2190, Avg Reward: -143.3019461915076
# Update #2200, Avg Reward: -126.9743841960169
# Update #2210, Avg Reward: -137.16875621628296
# Update #2220, Avg Reward: -136.04889537361638
# Update #2230, Avg Reward: -130.80314749833053
# Update #2240, Avg Reward: -129.2432614522021
# Update #2250, Avg Reward: -130.86558700686209
# Update #2260, Avg Reward: -132.6761234647573
# Update #2270, Avg Reward: -138.17575035478816
# Update #2280, Avg Reward: -130.2074625590342
# Update #2290, Avg Reward: -132.94198035337246
# Update #2300, Avg Reward: -135.63171375782548
# Update #2310, Avg Reward: -132.6377730304531
# Update #2320, Avg Reward: -131.0842535029898
# Update #2330, Avg Reward: -124.32095464234074
# Update #2340, Avg Reward: -130.4398272159986
# Update #2350, Avg Reward: -138.48463484008516
# Update #2360, Avg Reward: -139.39255094963897
# Update #2370, Avg Reward: -133.42874745077933
# Update #2380, Avg Reward: -131.2543507192782
# Update #2390, Avg Reward: -138.1670300229085
# Update #2400, Avg Reward: -128.0371466397457
# Update #2410, Avg Reward: -135.95785710246557
# Update #2420, Avg Reward: -142.52564229339612
# Update #2430, Avg Reward: -135.0504513876524
# Update #2440, Avg Reward: -141.02086492967246
# Update #2450, Avg Reward: -125.30484037903508
# Update #2460, Avg Reward: -122.17885111310197
# Update #2470, Avg Reward: -126.53820906605253
# Update #2480, Avg Reward: -131.67628793565308
# Update #2490, Avg Reward: -139.94157547715335
# Update #2500, Avg Reward: -125.90616690606221
# Update #2510, Avg Reward: -124.9665679002218
# Update #2520, Avg Reward: -130.2979859644079
# Update #2530, Avg Reward: -129.8568186782969
# Update #2540, Avg Reward: -125.30196149832223
# Update #2550, Avg Reward: -123.89060455690328
# Update #2560, Avg Reward: -134.28566681553596
# Update #2570, Avg Reward: -125.12198199719539
# Update #2580, Avg Reward: -126.99704318088394
# Update #2590, Avg Reward: -123.68771915872962
# Update #2600, Avg Reward: -119.53572229985441
# Update #2610, Avg Reward: -132.43437265880976
# Update #2620, Avg Reward: -124.46196088839625
# Update #2630, Avg Reward: -128.28492636409953
# Update #2640, Avg Reward: -139.52237718013527
# Update #2650, Avg Reward: -132.76736516688703
# Update #2660, Avg Reward: -132.02871369004885
# Update #2670, Avg Reward: -131.1195419917347
# Update #2680, Avg Reward: -133.5698789749551
# Update #2690, Avg Reward: -126.88370408421281
# Update #2700, Avg Reward: -134.615051669355
# Update #2710, Avg Reward: -117.35976463965521
# Update #2720, Avg Reward: -127.40864978425245
# Update #2730, Avg Reward: -134.1331169210164
# Update #2740, Avg Reward: -129.10715048478903
# Update #2750, Avg Reward: -124.39908646827469
# Update #2760, Avg Reward: -130.04459390144623
# Update #2770, Avg Reward: -129.96668294070386
# Update #2780, Avg Reward: -127.97431858576108
# Update #2790, Avg Reward: -133.02014838301295
# Update #2800, Avg Reward: -130.38253832830605
# Update #2810, Avg Reward: -126.65699137058498
# Update #2820, Avg Reward: -134.03554348192569
# Update #2830, Avg Reward: -138.81898109048387
# Update #2840, Avg Reward: -125.94298591707279
# Update #2850, Avg Reward: -127.16235180320409
# Update #2860, Avg Reward: -131.32028981676655
# Update #2870, Avg Reward: -119.13685197866216
# Update #2880, Avg Reward: -141.96519217835117
# Update #2890, Avg Reward: -150.7414260465034
# Update #2900, Avg Reward: -137.2134933862166
# Update #2910, Avg Reward: -128.44699513573562
# Update #2920, Avg Reward: -132.7449906950147
# Update #2930, Avg Reward: -129.8500242692872
# Update #2940, Avg Reward: -136.7194990669346
# Update #2950, Avg Reward: -128.96441767971368
# Update #2960, Avg Reward: -132.96146777788832
# Update #2970, Avg Reward: -137.0870687507445
# Update #2980, Avg Reward: -139.62735569249267
# Update #2990, Avg Reward: -121.58594953481789
# Update #3000, Avg Reward: -134.80275367639257
# Update #3010, Avg Reward: -128.88629220205374
# Update #3020, Avg Reward: -117.12956149102351
# Update #3030, Avg Reward: -141.82772678971463
# Update #3040, Avg Reward: -121.71926625480194
# Update #3050, Avg Reward: -133.56264373443037
# Update #3060, Avg Reward: -124.22993886927154
# Update #3070, Avg Reward: -131.62924289726203
# Update #3080, Avg Reward: -119.71606420494179
# Update #3090, Avg Reward: -130.0612416640185
# Update #3100, Avg Reward: -135.29688726470968
# Update #3110, Avg Reward: -133.3528492897254
# Update #3120, Avg Reward: -130.70257441104962
# Update #3130, Avg Reward: -131.38703786187983
# Update #3140, Avg Reward: -131.98611362614798
# Update #3150, Avg Reward: -130.37238101546035
# Update #3160, Avg Reward: -129.79887847549784
# Update #3170, Avg Reward: -134.12598863954116
# Update #3180, Avg Reward: -133.24012889575016
# Update #3190, Avg Reward: -129.8265339172123
# Update #3200, Avg Reward: -130.200309231016
# Update #3210, Avg Reward: -131.00427140687268
# Update #3220, Avg Reward: -128.93376907008442

# %%
ec.render_episodes(network, 5, max_steps) # Render an episode to see the result
